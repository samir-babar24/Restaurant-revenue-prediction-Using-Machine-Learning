# %%
#linear regression prooject
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


viruu=pd.read_csv("restaurant1(edited).csv")
print(viruu.head())
print("\n\n")
print(viruu.dtypes)
print("\n\n")
print(viruu.isnull().sum())

samm=viruu.drop('ParkingAvailability',axis=1)
# Out:
#            Name  Location   Cuisine  Rating  Seats  AverageMealPrice  \
# 0  Restaurant 0     Rural  Japanese     4.0     38             73.98
# 1  Restaurant 1  Downtown   Mexican     3.2     76             28.11
# 2  Restaurant 2     Rural   Italian     4.7     48             48.29
# 3  Restaurant 3     Rural   Italian     4.4     34             51.55
# 4  Restaurant 4  Downtown  Japanese     4.9     88             75.98
#
#    MarketingBudget  SocialMediaFollowers  ChefExperienceYears  \
# 0             2224                 23406                   13
# 1             4416                 42741                    8
# 2             2796                 37285                   18
# 3             1167                 15214                   13
# 4             3639                 40171                    9
#
#    NumberofReviews  AvgReviewLength  AmbienceScore  ServiceQualityScore  \
# 0              185       161.924906            1.3                  7.0
# ...

# %%
X =samm.iloc[:,3:-1]
y =samm.iloc[ : ,-1]

#trainig anf the testing of the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#using linear regresssion here as modell and traianing it
model = LinearRegression()
model.fit(X_train, y_train)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)

print("Sir ,Please fill below given terms for your predictionnn  !!!!!!!\n")
#taking user inut for prediction
rating = float(input("Enter the value for hotelRating in between  1 to 5: "))
seats = float(input("Enter the value for Seats in hotel: "))
average_meal_price = float(input("Enter the value for Average Meal Price in hotel in $: "))
marketing_budget = float(input("Enter the value of hotel Marketing Budget  in $: "))
social_media_followers = float(input("Enter the value for Social Media Followers of hotel: "))
chef_experience_years = float(input("Enter the value for Chef Experience Years: "))
number_of_reviews = float(input("Enter the value for Number of Reviews you got today?: "))
avg_review_length = float(input("Enter the value for Average Review Length: "))
ambience_score = float(input("Enter the value for Ambience Score between 1 to 10: "))
service_quality_score = float(input("Enter the value for Service Quality Score between 1 to 10: "))
weekday_reservations = float(input("Enter the value for Weekday Reservations: "))

#creating this into a dataframe
adwait_dataframe = [
    rating, seats, average_meal_price, marketing_budget,
    social_media_followers, chef_experience_years, number_of_reviews,
    avg_review_length, ambience_score, service_quality_score, weekday_reservations
]
user_input = pd.DataFrame([adwait_dataframe], columns=X.columns)

#making prediction
print("\n Thank you so much sir ,for giving our machine valuable time \n\n This is your prediction for hotel revenue:\n")

predicted_revenue = model.predict(user_input)
print(f"Predicted Revenue: ${predicted_revenue[0]:.2f}")
# Out:
# Sir ,Please fill below given terms for your predictionnn  !!!!!!!
#
# Enter the value for hotelRating in between  1 to 5: 5
# Enter the value for Seats in hotel: 200
# Enter the value for Average Meal Price in hotel in $: 80
# Enter the value of hotel Marketing Budget  in $: 2000
# Enter the value for Social Media Followers of hotel: 5000
# Enter the value for Chef Experience Years: 5
# Enter the value for Number of Reviews you got today?: 500
# Enter the value for Average Review Length: 4
# Enter the value for Ambience Score between 1 to 10: 4
# Enter the value for Service Quality Score between 1 to 10: 8
# Enter the value for Weekday Reservations: 500
#
#  Thank you so much sir ,for giving our machine valuable time
#
#  This is your prediction for hotel revenue:
#
# Predicted Revenue: $2551912.07

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, model.predict(X_test), color='blue', alpha=0.5)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
plt.xlabel('Actual Revenue')
plt.ylabel('Predicted Revenue')
plt.title('Actual vs Predicted Revenue')
plt.grid()
plt.show()
